# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel="ibm_cloud", token="TrGagFtRnQBMMBfD__HQwwLIacLYXNfph12CL1c8pZPt", instance="crn:v1:bluemix:public:quantum-computing:us-east:a/546fb41a6c4445218104ba4fcad6d4b4:208e9cb3-e996-49c8-923d-2f9cc2981b68::")


program_inputs = {'iterations': 1}
#options = {"backend_name": ""}
job = service.run(program_id="hello-world",
                
                  inputs=program_inputs
                 )
print(f"job id: {job.job_id}")
result = job.result()
print(result)
# Out:
# job id: ccms5qsrb0h8fubeqeeg
# ---------------------------------------------------------------------------
# RuntimeJobFailureError                    Traceback (most recent call last)
# Cell In [9], line 13
#       8 job = service.run(program_id="hello-world",
#       9
#      10                   inputs=program_inputs
#      11                  )
#      12 print(f"job id: {job.job_id}")
# ---> 13 result = job.result()
#      14 print(result)
#
# File ~/opt/anaconda3/envs/ENV_NAME/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:182, in RuntimeJob.result(self, timeout, decoder)
#     180 self.wait_for_final_state(timeout=timeout)
#     181 if self._status == JobStatus.ERROR:
# --> 182     raise RuntimeJobFailureError(
#     183         f"Unable to retrieve job result. " f"{self.error_message()}"
#     184     )
#     185 result_raw = self._api_client.job_results(job_id=self.job_id)
#     186 self._results = _decoder.decode(result_raw) if result_raw else None
#
# RuntimeJobFailureError: 'Unable to retrieve job result. Job ccms5qsrb0h8fubeqeeg has failed:\n2022-09-23T09:30:06.983946867-05:00 09/23/2022 02:30:06 PM - jaeger_tracing - INFO Initializing Jaeger Tracer with UDP reporter\n2022-09-23T09:30:06.989473484-05:00 09/23/2022 02:30:06 PM - jaeger_tracing - INFO Using sampler ConstSampler(True)\n2022-09-23T09:30:06.990588841-05:00 09/23/2022 02:30:06 PM - jaeger_tracing - INFO opentracing.tracer initialized to <jaeger_client.tracer.Tracer object at 0x7f324f73a520>[app_name=ntc-job]\n2022-09-23T09:30:07.172506750-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.18072 (ms)\n2022-09-23T09:30:07.173516545-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.09108 (ms)\n2022-09-23T09:30:07.174015562-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.07963 (ms)\n2022-09-23T09:30:07.174533606-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.07772 (ms)\n2022-09-23T09:30:07.174970444-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.07725 (ms)\n2022-09-23T09:30:07.175528894-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assembly Time - 0.09394 (ms)\n2022-09-23T09:30:07.176058419-05:00 09/23/2022 02:30:07 PM - qiskit.compiler.assembler - INFO Total Assemb